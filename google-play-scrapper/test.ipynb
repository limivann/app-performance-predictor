# %%
import pandas as pd
data = pd.read_csv("./output/output.csv")
data
# Out:
#                                              APP_NAME    RATING    CATEGORY  \
# 0                                    Airport Security  4.100358      Casual
# 1                                   Frozen Honey ASMR  4.215625      Casual
# 2                      Merge Master - Dinosaur Fusion  4.168724      Arcade
# 3                                         Battery Run  3.905983      Action
# 4                                  Theme Park Fun 3D!  4.100000  Simulation
# 5                            Dress Up Game: Babi Doll  3.858586      Casual
# 6                                          Money Rush  4.147885      Casual
# 7                                              Roblox  4.440141   Adventure
# 8                      Stone Grass — Mowing Simulator  3.320574      Arcade
# 9                                          Paper Fold  4.383036      Puzzle
# 10                     Bumble - Dating. Friends. Bizz  2.821547      Dating
# ...
