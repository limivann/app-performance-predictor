# %%
import pandas as pd
data = pd.read_csv("./output/output_v1.csv")
data
# Out:
#        APP_NAME    RATING      CATEGORY      COLLECTIONS  RATING_COUNT  \
# 0    Google One  4.388100  Productivity      topgrossing        301744
# 1  HotSchedules  3.204141  Productivity  topselling_paid         22053
# 2        TikTok  4.534216        Social  topselling_free      45987813
#
#    1_STAR_RATINGS  2_STAR_RATINGS  3_STAR_RATINGS  4_STAR_RATINGS  \
# 0           22525            6977           19300           34979
# 1            7516            1687            1369            1730
# 2         3300633          733165         1404664         3208972
#
#    5_STAR_RATINGS  ...  CURRENCY                SIZE         DEVELOPER  \
# 0          217950  ...       USD  Varies with device        Google LLC
# 1            9746  ...       USD                 39M      HotSchedules
# 2        37340354  ...       USD                 97M  TikTok Pte. Ltd.
#
#    CONTENT_RATING  FAMILY_GENRE  AD_SUPPORTED IN_APP_PURCHASES RELEASED_DATE  \
# ...
